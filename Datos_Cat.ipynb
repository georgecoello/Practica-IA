# %%
import pandas as pd

# %%
adidas = pd.read_csv("adidas.csv")

# %%
adidas.head(10)
# Out:
#                                                  url  \
# 0  https://www.adidas.com/us/beach-shorts/FJ5089....
# 1  https://www.adidas.com/us/five-ten-kestrel-lac...
# 2  https://www.adidas.com/us/mexico-away-jersey/G...
# 3  https://www.adidas.com/us/five-ten-hiangle-pro...
# 4  https://www.adidas.com/us/mesh-broken-stripe-p...
# 5  https://www.adidas.com/us/eqt-spikeless-golf-s...
# 6  https://www.adidas.com/us/adicross-hybrid-shor...
# 7  https://www.adidas.com/us/tiro-21-windbreaker/...
# 8  https://www.adidas.com/us/classic-3-stripes-sw...
# 9  https://www.adidas.com/us/tiro-21-windbreaker/...
#
#                                               name     sku  selling_price  \
# 0                                     Beach Shorts  FJ5089             40
# 1        Five Ten Kestrel Lace Mountain Bike Shoes  BC0770            150
# 2                               Mexico Away Jersey  GC7946             70
# 3  Five Ten Hiangle Pro Competition Climbing Shoes  FV4744            160
# ...

# %%
adidas.shape
# Out:
# (845, 20)

# %%
adidas.dtypes
# Out:
# url                object
# name               object
# sku                object
# selling_price       int64
# original_price     object
# currency           object
# availability       object
# color              object
# category           object
# source             object
# source_website     object
# breadcrumbs        object
# description        object
# brand              object
# images             object
# country            object
# language           object
# average_rating    float64
# reviews_count       int64
# crawled_at         object
# dtype: object

# %%
cols = ['url', 'name', 'original_price', 'currency',
       'availability', 'color', 'category', 'source', 'source_website',
       'breadcrumbs', 'description', 'brand', 'images', 'country', 'language', 'crawled_at']

# %%
cols_validas = []
cols_many_levels = []
cols_one_level = []

size_df = adidas.shape[0]
umbral = 0.95

# %%
for c_ in cols:
    nivels = adidas.loc[:, [c_]].drop_duplicates().shape[0]
    if (nivels/size_df) >= umbral:
        cols_many_levels.append(c_)
    elif nivels == 1:
        cols_one_level.append(c_)
    else:
        cols_validas.append(c_)

# %%
adidas.loc[:, cols_many_levels]
# Out:
#                                                    url  \
# 0    https://www.adidas.com/us/beach-shorts/FJ5089....
# 1    https://www.adidas.com/us/five-ten-kestrel-lac...
# 2    https://www.adidas.com/us/mexico-away-jersey/G...
# 3    https://www.adidas.com/us/five-ten-hiangle-pro...
# 4    https://www.adidas.com/us/mesh-broken-stripe-p...
# ..                                                 ...
# 840  https://www.adidas.com/us/supernova-plus-shoes...
# 841  https://www.adidas.com/us/choigo-shoes/H00667....
# 842  https://www.adidas.com/us/daily-3.0-shoes/GZ77...
# 843  https://www.adidas.com/us/daily-3.0-shoes/GZ77...
# 844  https://www.adidas.com/us/choigo-shoes/FY6503....
#
#                                                 images  \
# 0    https://assets.adidas.com/images/w_600,f_auto,...
# 1    https://assets.adidas.com/images/w_600,f_auto,...
# 2    https://assets.adidas.com/images/w_600,f_auto,...
# 3    https://assets.adidas.com/images/w_600,f_auto,...
# ...

# %%
adidas.loc[:, cols_one_level].drop_duplicates()
# Out:
#   currency                source          source_website   brand country  \
# 0      USD  adidas United States  https://www.adidas.com  adidas     USA
#
#   language
# 0       en

# %%
adidas.loc[:, cols_validas]
# Out:
#                                                 name original_price  \
# 0                                       Beach Shorts            NaN
# 1          Five Ten Kestrel Lace Mountain Bike Shoes            NaN
# 2                                 Mexico Away Jersey            NaN
# 3    Five Ten Hiangle Pro Competition Climbing Shoes            NaN
# 4                      Mesh Broken-Stripe Polo Shirt            NaN
# ..                                               ...            ...
# 840                                 Supernova+ Shoes           $120
# 841                                     Choigo Shoes           $100
# 842                                  Daily 3.0 Shoes            $50
# 843                                  Daily 3.0 Shoes            $50
# 844                                     Choigo Shoes           $100
#
#     availability  color  category     breadcrumbs  \
# 0        InStock  Black  Clothing  Women/Clothing
# ...

# %%
adidas.loc[:,["color"]].drop_duplicates()
# Out:
#           color
# 0         Black
# 1          Grey
# 2         White
# 4          Blue
# 15       Purple
# 16         Pink
# 18        Green
# 28       Yellow
# 82          Red
# 94   Multicolor
# 102        Gold
# 131    Burgundy
# 214       Beige
# 356      Orange
# 426       Multi
# 458   Turquoise
# 533      Silver
# 793       Brown

# %%
levels = adidas.groupby(["color"], as_index = False).agg({"sku" : ["count"]})

# %%
levels.columns = levels.columns. droplevel(1)

# %%
levels
# Out:
#          color  sku
# 0        Beige    6
# 1        Black  187
# 2         Blue  104
# 3        Brown    1
# 4     Burgundy    9
# 5         Gold    3
# 6        Green   59
# 7         Grey   81
# 8        Multi    4
# 9   Multicolor   20
# 10      Orange   11
# 11        Pink   62
# 12      Purple   31
# 13         Red   25
# 14      Silver    1
# 15   Turquoise    2
# 16       White  222
# 17      Yellow   17

# %%
levels["Percentage"] = levels["sku"]/adidas.shape[0]
levels.sort_values(["Percentage"], ascending = False)
# Out:
#          color  sku  Percentage
# 16       White  222    0.262722
# 1        Black  187    0.221302
# 2         Blue  104    0.123077
# 7         Grey   81    0.095858
# 11        Pink   62    0.073373
# 6        Green   59    0.069822
# 12      Purple   31    0.036686
# 13         Red   25    0.029586
# 9   Multicolor   20    0.023669
# 17      Yellow   17    0.020118
# 10      Orange   11    0.013018
# 4     Burgundy    9    0.010651
# 0        Beige    6    0.007101
# 8        Multi    4    0.004734
# 5         Gold    3    0.003550
# 15   Turquoise    2    0.002367
# 14      Silver    1    0.001183
# 3        Brown    1    0.001183

# %%
levels.sort_values(["Percentage"], ascending = True).shape
# Out:
# (18, 4)

# %%
levels["Color_t"] = "Others"

# %%
levels
# Out:
#          color  sku  Percentage Color_t
# 0        Beige    6    0.007101  Others
# 1        Black  187    0.221302  Others
# 2         Blue  104    0.123077  Others
# 3        Brown    1    0.001183  Others
# 4     Burgundy    9    0.010651  Others
# 5         Gold    3    0.003550  Others
# 6        Green   59    0.069822  Others
# 7         Grey   81    0.095858  Others
# 8        Multi    4    0.004734  Others
# 9   Multicolor   20    0.023669  Others
# 10      Orange   11    0.013018  Others
# 11        Pink   62    0.073373  Others
# 12      Purple   31    0.036686  Others
# 13         Red   25    0.029586  Others
# 14      Silver    1    0.001183  Others
# 15   Turquoise    2    0.002367  Others
# 16       White  222    0.262722  Others
# 17      Yellow   17    0.020118  Others

# %%
levels["Color_t"] = levels.apply(lambda r: r["color"] if r["Percentage"] >= 0.09 else r["Color_t"], axis=1)

# %%
levels.loc[:, ["color", "Color_t"]]
# Out:
#          color Color_t
# 0        Beige  Others
# 1        Black   Black
# 2         Blue    Blue
# 3        Brown  Others
# 4     Burgundy  Others
# 5         Gold  Others
# 6        Green  Others
# 7         Grey    Grey
# 8        Multi  Others
# 9   Multicolor  Others
# 10      Orange  Others
# 11        Pink  Others
# 12      Purple  Others
# 13         Red  Others
# 14      Silver  Others
# 15   Turquoise  Others
# 16       White   White
# 17      Yellow  Others

# %%
adidas.merge(levels, on=["color"], how="inner")
# Out:
#                                                    url  \
# 0    https://www.adidas.com/us/beach-shorts/FJ5089....
# 1    https://www.adidas.com/us/five-ten-hiangle-pro...
# 2    https://www.adidas.com/us/adicross-hybrid-shor...
# 3    https://www.adidas.com/us/tiro-21-windbreaker/...
# 4    https://www.adidas.com/us/classic-3-stripes-sw...
# ..                                                 ...
# 840  https://www.adidas.com/us/aggies-long-sleeve-q...
# 841  https://www.adidas.com/us/zx-1k-boost-shoes/FX...
# 842  https://www.adidas.com/us/ultraboost-dna-1.0-s...
# 843  https://www.adidas.com/us/gamemode-firm-ground...
# 844  https://www.adidas.com/us/originals-sunglasses...
#
#                                                 name   sku_x  selling_price  \
# 0                                       Beach Shorts  FJ5089             40
# 1    Five Ten Hiangle Pro Competition Climbing Shoes  FV4744            160
# ...
